# %% [markdown]
# # 🤔 P2.1.1.2 – Machine Learning Foundations
#
# ## Topic: Why Machine Learning Exists

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain why machine learning is needed in the modern world
# - Distinguish ML from traditional programming
# - Understand how ML fits into the broader AI landscape
# - Recognize real-world scenarios where ML is essential

# %% [markdown]
# ## 1️⃣ What is AI vs ML?
#
# - **AI (Artificial Intelligence):** Rule-based logic. Machines that act smart by following rules we write.
# - **ML (Machine Learning):** Learning from data. Instead of writing rules, we give examples and let the machine learn patterns.

# %% [markdown]
# ## 2️⃣ Why Did ML Come Into Picture?
#
# ### ❌ If No ML:
# - We must write rules manually for every situation.
# - Impossible for image recognition.
# - Impossible for language understanding.
# - Rules explode combinatorially!
# **Example:** How would you write rules to detect a cat in a photo?
# → Impossible manually!

# %% [markdown]
# ## 3️⃣ Essence of ML
#
# Instead of writing rules, we give examples, and the machine learns patterns.
# > **ML = Let the machine learn from data!**

# %% [markdown]
# ## 4️⃣ What Happens Internally?
#
# **Visual:**
#
# ```
#            Algorithm
#               |
# Data --->  Model  ---> Prediction
# ```
#
# - **Data:** Examples we provide
# - **Algorithm:** Mathematical procedure
# - **Model:** Trained mathematical object
# - **Prediction:** Output for new input

# %% [markdown]
# ---
# ## 🧮 Mini Linear Regression Example
#
# Suppose you have:
#
# | X | y |
# |---|---|
# | 1 | 2 |
# | 2 | 4 |
# | 3 | 6 |
# | 4 | 8 |
# The model learns: y = 2x
# If you give x = 5, the model predicts y = 10.
# > **This is the essence of ML: learning patterns from data!**

# %% [markdown]
# ## 📝 Key Takeaways
#
# - ML is needed when rules are too complex or data-driven patterns are required.
# - Traditional programming relies on explicit rules; ML learns from data.
# - ML is a core part of the AI ecosystem, enabling automation and smarter systems.
# - Real-world ML applications include spam detection, recommendation systems, and more.
