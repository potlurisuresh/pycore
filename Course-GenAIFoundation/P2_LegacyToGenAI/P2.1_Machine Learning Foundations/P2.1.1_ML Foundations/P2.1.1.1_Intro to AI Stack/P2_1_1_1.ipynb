# %% [markdown]
# # 🤖 P2.1.1.1 –  Intro to the AI Stack
#
# ## 🚀 Understanding AI, ML, DL, NLP & Generative AI
#
# > **Welcome!** In this notebook, we'll break down the buzzwords and concepts in AI so you can start your journey with confidence!
#
# ---

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Explain the difference between AI, ML, DL, NLP, and Generative AI
# - Understand the structure of the modern AI stack
# - Recognize where each technology fits in real-world applications
# - Build confidence to start your AI/ML journey

# %% [markdown]
# ## ❓ Why Are We Learning This?
#
# Before writing any code… 🧑‍💻
# Before building any models… 🏗️
#
# We must understand the AI ecosystem. 🌐
#
# ### 💭 Many beginners feel:
# - 🤯 AI is too complex
# - 📐 AI requires heavy math
# - 👨‍🔬 AI is only for researchers
# - 🪄 AI is 'magic'
#
# > **This notebook removes that mental block!**
#
# After this notebook, you will clearly understand:
# - 🤖 What AI really is
# - 🧠 How ML is different from AI
# - 🕸️ What Deep Learning actually means
# - 💬 Where NLP fits
# - ✨ What Generative AI really does
#
# ---

# %% [markdown]
# ## 🏗️ The Big Picture
#
# AI is not one single thing. It's a stack of ideas built on top of each other!
#
# We'll peel back the layers from the outside in. Ready? Let's go! 🚦

# %% [markdown]
# ## 1️⃣ Artificial Intelligence (AI)
#
# **AI means:** Machines that act smart! 🧠
#
# It is the broad idea of making computers behave intelligently.
#
# ### What can AI do?
# - 📝 Follow rules
# - 🧩 Solve problems
# - 🕹️ Make decisions
#
# **Examples:**
# - 🚦 Traffic light system
# - ♟️ Chess engine
# - 🤖 Rule-based chatbot
#
# > **AI = Smart behavior!**
#
# ---

# %% [markdown]
# ## 2️⃣ Machine Learning (ML)
#
# **ML is a subset of AI.**
#
# Instead of writing rules, we give the machine data! 📊
# The system learns patterns from data.
#
# ### What can ML do?
# - 🧑‍🏫 Learns from examples
# - 📈 Improves with more data
# - 🔮 Makes predictions
#
# **Examples:**
# - 🚫 Spam detection
# - 💳 Credit scoring
# - 🍿 Movie recommendations
#
# > **ML = Learning from data!**
#
# ---

# %% [markdown]
# > **Quick Recap:**
# - 🤖 AI uses rules.
# - 🧠 ML learns from data.

# %% [markdown]
# ## 3️⃣ Deep Learning (DL)
#
# **DL is a subset of ML.**
#
# It uses neural networks with many layers, inspired by the human brain! 🧠
#
# ### What can DL do?
# - 🕸️ Learns complex patterns automatically
# - 🖼️ Works very well with images and speech
# - 💻 Requires large data and computing power
#
# **Examples:**
# - 🧑‍💻 Face recognition
# - 🗣️ Voice assistants
# - 🚗 Self-driving cars
#
# > **DL = Learning complex patterns automatically!**
#
# ---

# %% [markdown]
# ## 4️⃣ Natural Language Processing (NLP)
#
# **NLP focuses on human language!** 🗣️
#
# It allows machines to:
# - 📖 Read text
# - 🧠 Understand meaning
# - 💬 Respond in language
#
# NLP can use:
# - 📝 Rule-based AI
# - 🧠 Machine Learning
# - 🕸️ Deep Learning
#
# Modern NLP mostly uses Deep Learning (Transformers).
#
# **Examples:**
# - 🌐 Google Translate
# - 🤖 Chatbots
# - 😊 Sentiment analysis
#
# > **NLP = Language understanding!**
#
# ---

# %% [markdown]
# ## 5️⃣ Generative AI (GenAI)
#
# **GenAI creates new content!** ✨
#
# It doesn't just analyze, it generates!
#
# It can create:
# - 📝 Text
# - 🖼️ Images
# - 💻 Code
# - 🎵 Music
# - 🎬 Videos
#
# **Examples:**
# - 🤖 ChatGPT
# - 🖼️ Image generators
# - 👨‍💻 Code assistants
#
# > **GenAI = Creation, not just prediction!**
#
# ---

# %% [markdown]
# ## 🧘 Removing the Fear Around AI
#
# AI is not magic. ✨
# AI is not consciousness. 🧠
# AI does not think like humans. 👤
#
# It is mathematics + data + computation. ➕
#
# You do **not** need to:
# - 🧮 Be a math genius
# - 🎓 Be a PhD researcher
# - 🏃‍♂️ Understand everything at once
#
# You only need:
# - 💡 Clear concepts
# - 🪜 Step-by-step learning
#
# ---

# %% [markdown]
# # 🟢 Venn Diagram
#
# Below is a visual representation of how these fields overlap!

# %% [markdown]
# ![Venn Diagram](attachment:image.png)
#
# ---
#
# > **🎯 Challenge Yourself:** Can you explain the difference between AI, ML, DL, NLP, and GenAI to a friend in one sentence each? Try it below!

# %% [markdown]
# ## 📝 Key Takeaways
#
# - AI is a broad field focused on making machines act smart; ML is a subset that learns from data.
# - Deep Learning, NLP, and Generative AI are specialized areas within the AI stack.
# - Understanding the stack helps you see how different technologies connect and where to start your learning journey.
# - The AI ecosystem is approachable—no magic, just logic and data!
