# %% [markdown]
# # 🧬 P2.1.1.5 – Machine Learning Foundations
#
# ## Topic: Data Types, Vectorization & Train-Test Split

# %% [markdown]
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# - Identify different data types used in machine learning
# - Explain why vectorization is necessary for text data
# - Describe common vectorization techniques
# - Understand the importance of splitting data into training and testing sets

# %% [markdown]
# ## 🔄 Vectorization: Converting Text to Numbers
#
# **What is Vectorization?**
#
# - 🔄 Vectorization is the process of converting text data into numeric form (vectors) so that machine learning models can use it.
#
#
# **Why do we need it?**
#
# - 🤖 ML models only accept numbers. Vectorization lets us use text, emails, reviews, or any language data in ML.
#
#
# **Common Techniques:**
#
# - 🧰 Bag of Words, TF-IDF, Word Embeddings (Word2Vec, GloVe, etc.)
#
#
#
# **What happens if we skip vectorization?**
#
# - 🚫 The model cannot process text and will fail to learn anything from it.

# %% [markdown]
# ## 📂 Train-Test Split: Why We Need It
#
# **What is Train-Test Split?**
#
# - It is the process of dividing your data into two sets: one for training the model and one for testing its performance.
#
#
# **Why do we need it?**
#
# - To check if the model can generalize to new, unseen data.
#
#
# **Purpose:**
#
# - Prevents overfitting (model memorizing training data instead of learning patterns).
#
# - Gives a realistic estimate of how well the model will perform in the real world.
#
#
# **How is it done?**
#
# - Common split: 80% training, 20% testing (can vary).
#
#
#
# **If we skip this step:**
#
# - We risk building a model that works well on training data but fails on new data.

# %% [markdown]
# ## 💡 Key Takeaways & Common Pitfalls
#
# - ML models require numeric data; text must be converted (vectorized).
# - Always split your data for training and testing to avoid overfitting.
# - Check your data quality: missing values, outliers, and incorrect labels can mislead the model.
# - Use factual, real-world examples and avoid blindly following steps—understand why each step is needed.
# - If you skip vectorization or train-test split, your model will not work as expected.
#
# **Remember:** Machine learning is not just about running code—it's about understanding the data, the process, and the limitations!
