# %% [markdown]
# # 📘 P1.3.1.1 – Client–Server Basics
# ## Topic: Client, Server, Request & Response

# %% [markdown]
# ## 🎯 Learning Objectives
# By the end of this notebook, you will:
# - Define **client** and **server** in behavioral terms
# - Identify common client and server examples
# - Distinguish between **request** and **response**
# - Explain what an **IP address** and **port** represent
# - Describe the basic client–server flow

# %% [markdown]
# ![3.png](attachment:161c9639-cef3-4413-a4ba-d983170aba9a.png)

# %% [markdown]
# ## 🧩 Client (Behavioral Definition)
# A **client** is any system that **requests data or services** from a server.
#
# **Key idea:** Whoever **initiates communication** is the client.
# This is behavioral, not device-based.

# %% [markdown]
# ## 🧾 Examples of Clients
# - **Browser** (Chrome, Edge, Firefox)
# - **Web app** (React frontend)
# - **Mobile app**
# - **Postman** or other API tools
# - **Python script**
# - **curl**
# - **Another backend service**

# %% [markdown]
# ## 🧩 Server
# A **server** is a system that **listens for requests** and **sends responses**.
#
# **Important clarity:**
# - A server is not always a big machine
# - Your laptop running Flask Application can act as a server

# %% [markdown]
# ## 🧾 Examples of Servers
# - **Web server** hosting an API
# - **Backend application server**
# - **Database server**

# %% [markdown]
# ## 📩 Request vs Response
# - A **request** is a message sent by a client asking the server to perform an action.
# - A **response** is the message sent back by the server after processing the request.

# %% [markdown]
# ![2.png](attachment:14690755-fbc4-44b9-bab8-bf256bcfd65d.png)

# %% [markdown]
# ## 🌐 IP Address & Port Number
# **IP address = address of the computer.**
# It is a unique number that identifies a device on a network.
#
# **Examples:**
# - 192.168.1.10
# - 142.250.182.14
#
# **Port number = address of the application.**
# One computer can run many apps. A port number identifies a specific application running on a machine.
#
# **Examples :**  One Computer can run:
# - Web server
# - Database
# - Email server
# - Backend API
#
# **How does the system know which program should handle the request?**
# Using a port number.
#
# **Simple real example:**
# `localhost:3000`
# - `localhost` → your machine (IP)
# - `3000` → the app running on that port

# %% [markdown]
# ![1.png](attachment:0bb0f4e6-ce10-48d4-b185-0c0aed68d633.png)

# %% [markdown]
# ### ✅ Key Takeaways
# - **Client** initiates communication by sending a request
# - **Server** listens and responds after processing
# - **Request** asks for an action; **response** returns results
# - **IP address** identifies the machine; **port** identifies the app
# - Client–server roles are **behavioral**, not device-based
