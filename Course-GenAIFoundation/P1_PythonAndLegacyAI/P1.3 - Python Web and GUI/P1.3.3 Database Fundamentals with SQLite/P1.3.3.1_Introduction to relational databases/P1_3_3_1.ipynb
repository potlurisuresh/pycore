# %% [markdown]
# # 📘 P1.3.4.1 – Database Fundamentals
# ## Topic: Introduction to Databases
#
# ## 🎯 Learning Objectives
# By the end of this notebook, you will:
# - Understand what a database is
# - Understand why we use databases instead of filesystem
# - Recognize common types of databases
# - Understand relational databases at a high level
# - Explain tables, rows, columns, and data types
# - Know that SQL is used to manage relational data
#
# ## 💾 What is a Database?
# A **database** is an organized place to store data so it can be **saved, searched, updated, and shared** easily.
#
# Think of it as a **smart storage system** for data.

# %% [markdown]
# <img src="7.png" width="600"/>

# %% [markdown]
# ## ❓ Why Do We Need a Database (If We Already Have Files)?
# Files can store data, but databases make data **easy to manage**.
#
# **Databases help when you need:**
# - **Fast search** (find data quickly)
# - **Reliable updates** (no broken or duplicated data)
# - **Multiple users** (many people using data at the same time)
# - **Security & access control**
# - **Backups & recovery**
# - **Structured relationships** between data

# %% [markdown]
# <img src="8.png" width="600"/>

# %% [markdown]
# ## 🧩 Relational Databases
# A **relational database** stores data in **tables** and connects tables using relationships.
#
# **Examples:** SQLite, MySQL, PostgreSQL
#
# ## 📊 Tables, Rows, and Columns
# - **Table**: A collection of data organized into rows and columns.
# - **Row**: store individual records (one person per row)
# - **Column**: define the type of data (like name, age, email)
#
# ## 📊 Tiny Example: Two Connected Tables
#
# ### Users Table
# ### Users Table
# | id | name  | email            |
# |:--:|:------|:-----------------|
# | 1  | Alice | alice@mail.com   |
# | 2  | Bob   | bob@mail.com     |
#
#
# ### Orders Table
# | order_id | user_id | item   |
# |----------|---------|--------|
# | 101      | 1       | Laptop |
# | 102      | 1       | Mouse  |
# | 103      | 2       | Phone  |
#
# ---
#
# ### 🔗 The Connection (Relation)
#
# **`user_id` in the Orders table → `id` in the Users table**
#
# - Order 101: `user_id = 1` → connects to Alice
# - Order 102: `user_id = 1` → connects to Alice
# - Order 103: `user_id = 2` → connects to Bob
#
# ---
#
# ### ❓ What You Can Ask
#
# > *"Show me all orders for Alice"*
#
# The database finds Alice (id = 1) in the Users table, then finds all rows in the Orders table where `user_id = 1`.
#
# **Result:**
# - Laptop
# - Mouse
#
# That's a **relation** — tables connected by matching keys.
#
# ## 🧪 Data Types (Simple View)
# Each column has a **data type** that defines what it can store:
# - **INTEGER** – whole numbers (e.g., 42)
# - **TEXT** – words or sentences
# - **REAL** – decimal numbers (e.g., 3.14)
# - **BOOLEAN** – true/false
# - **DATE/TIME** – dates and times
#
# ## 🧾 Managing Relational Databases
# We use **SQL commands** to create, read, update, and delete data in relational databases.
#
# We will learn SQL CRUD commands in the next notebook.
#
# ### ✅ Key Takeaways
# - A **database** is organized storage for data
# - Databases make data **searchable, reliable, and shareable**
# - There are multiple database types for different needs
# - **Relational databases** store data in tables
# - Tables have **rows**, **columns**, and **data types**
# - **SQL** is used to manage relational data
