# %% [markdown]
# # Advanced Assessment 1: Multiple Choice
# Choose the correct answer for each question.

# %% [markdown]
# 1. Which HTTP header is used for authentication?
# A) Content-Type
# B) Authorization
# C) Accept
# D) Host

# %% [markdown]
# 2. What does CORS stand for?
# A) Cross-Origin Resource Sharing
# B) Content-Origin Resource Service
# C) Cross-Operation Resource Sharing
# D) None of the above

# %% [markdown]
# 3. Which status code means 'Unauthorized'?
# A) 200
# B) 401
# C) 403
# D) 404

# %% [markdown]
# 4. What is the main purpose of REST constraints?
# A) Security
# B) Scalability
# C) Data storage
# D) None of the above

# %% [markdown]
# 5. Which HTTP method is not idempotent?
# A) GET
# B) PUT
# C) POST
# D) DELETE

# %% [markdown]
# 6. What is the function of the OPTIONS method?
# A) Retrieve data
# B) Update data
# C) Describe communication options
# D) Delete data

# %% [markdown]
# 7. Which format is NOT commonly used for API responses?
# A) JSON
# B) XML
# C) CSV
# D) MP3

# %% [markdown]
# 8. What does a 204 status code mean?
# A) No Content
# B) Created
# C) Bad Request
# D) Forbidden

# %% [markdown]
# 9. Which HTTP method is used for partial updates?
# A) GET
# B) PATCH
# C) PUT
# D) DELETE

# %% [markdown]
# 10. What is the main benefit of statelessness in REST?
# A) Faster data transfer
# B) Easier scaling
# C) More security
# D) None of the above
