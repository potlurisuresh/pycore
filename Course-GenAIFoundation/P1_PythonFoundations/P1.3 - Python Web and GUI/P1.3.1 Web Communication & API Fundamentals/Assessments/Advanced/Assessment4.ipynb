# %% [markdown]
# # Advanced Assessment 4: True or False
# State whether each statement is True or False.

# %% [markdown]
# 1. The PATCH method is used for partial updates.

# %% [markdown]
# 2. 401 status code means 'Forbidden'.

# %% [markdown]
# 3. JSON is more verbose than XML.

# %% [markdown]
# 4. REST APIs must use HTTPS.

# %% [markdown]
# 5. The Accept header specifies the type of data the client can process.

# %% [markdown]
# 6. 204 status code means 'No Content'.

# %% [markdown]
# 7. CORS is a security feature in browsers.

# %% [markdown]
# 8. The PUT method is not idempotent.

# %% [markdown]
# 9. The Host header is required in HTTP/1.1 requests.

# %% [markdown]
# 10. 500 status code means 'Internal Server Error'.
