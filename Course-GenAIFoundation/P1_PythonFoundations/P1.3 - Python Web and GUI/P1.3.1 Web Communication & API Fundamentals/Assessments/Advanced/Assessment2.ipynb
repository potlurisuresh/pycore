# %% [markdown]
# # Advanced Assessment 2: Fill in the Blanks
# Fill in the blanks with the correct terms.

# %% [markdown]
# 1. The _____ header is used to specify the type of data sent in an HTTP request.

# %% [markdown]
# 2. _____ is a protocol for secure communication over a computer network.

# %% [markdown]
# 3. The _____ method is used to retrieve only the headers of a resource.

# %% [markdown]
# 4. _____ is a common format for API documentation.

# %% [markdown]
# 5. _____ is a tool for testing APIs.

# %% [markdown]
# 6. The _____ status code means 'Forbidden'.

# %% [markdown]
# 7. _____ is a lightweight data-interchange format.

# %% [markdown]
# 8. The _____ method is used to partially update a resource.

# %% [markdown]
# 9. _____ is a security feature that restricts web pages from making requests to a different domain.

# %% [markdown]
# 10. The _____ status code means 'Bad Request'.
