# %% [markdown]
# # Advanced Assessment 5: Mixed Questions
# A mix of MCQ, fill in the blanks, and short answer.

# %% [markdown]
# 1. (MCQ) Which HTTP method is used for partial updates?
# A) GET
# B) POST
# C) PATCH
# D) DELETE

# %% [markdown]
# 2. (Blank) The _____ status code means 'Unauthorized'.

# %% [markdown]
# 3. (Short Answer) What is the purpose of the Authorization header?

# %% [markdown]
# 4. (MCQ) Which of the following is NOT a valid HTTP status code?
# A) 200
# B) 201
# C) 999
# D) 404

# %% [markdown]
# 5. (Blank) _____ is a protocol for secure communication over a network.

# %% [markdown]
# 6. (Short Answer) What is the main benefit of statelessness in REST APIs?

# %% [markdown]
# 7. (MCQ) Which tool is commonly used for API testing?
# A) Postman
# B) Word
# C) Excel
# D) Paint

# %% [markdown]
# 8. (Blank) The _____ method is used to completely replace a resource.

# %% [markdown]
# 9. (Short Answer) What is CORS and why is it important?

# %% [markdown]
# 10. (MCQ) Which status code means 'No Content'?
# A) 200
# B) 201
# C) 204
# D) 404
