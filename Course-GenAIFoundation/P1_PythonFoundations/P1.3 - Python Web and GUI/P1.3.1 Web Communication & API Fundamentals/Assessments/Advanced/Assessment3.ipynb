# %% [markdown]
# # Advanced Assessment 3: Short Answer
# Answer each question in your own words.

# %% [markdown]
# 1. What is the purpose of the PATCH method in HTTP?

# %% [markdown]
# 2. Explain the concept of statelessness in REST APIs.

# %% [markdown]
# 3. What is the difference between 401 and 403 status codes?

# %% [markdown]
# 4. What is CORS and why is it important?

# %% [markdown]
# 5. What is the function of the OPTIONS method?

# %% [markdown]
# 6. What is an API endpoint? Give an example.

# %% [markdown]
# 7. What is the use of the Accept header in HTTP requests?

# %% [markdown]
# 8. What is the difference between PUT and PATCH methods?

# %% [markdown]
# 9. What is a 204 status code and when is it used?

# %% [markdown]
# 10. What is the main benefit of using JSON for API responses?
