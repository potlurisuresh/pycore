# %% [markdown]
# # Beginner Assessment 3: Fill in the Blanks
# Fill in each blank with the correct answer.

# %% [markdown]
# 1. The protocol used for secure web communication is _______.

# %% [markdown]
# 2. The default port for HTTP is _______.

# %% [markdown]
# 3. The part of a URL after the domain and before the query string is called the _______.

# %% [markdown]
# 4. The HTTP method used to retrieve data is _______.

# %% [markdown]
# 5. The response code _______ means the request was successful.

# %% [markdown]
# 6. The _______ method is used to send data to a server.

# %% [markdown]
# 7. _______ is a common web browser.

# %% [markdown]
# 8. The _______ header specifies the type of data sent in a request.

# %% [markdown]
# 9. The _______ status code means 'Not Found'.

# %% [markdown]
# 10. The _______ is the address of a resource on the web.
