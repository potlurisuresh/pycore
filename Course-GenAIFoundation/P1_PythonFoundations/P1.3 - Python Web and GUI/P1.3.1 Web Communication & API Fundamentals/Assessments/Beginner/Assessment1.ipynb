# %% [markdown]
# # Beginner Assessment 1: Multiple Choice
# Welcome! Answer each question by selecting the correct option.

# %% [markdown]
# 1. Which protocol is used for web communication?
#    - a) FTP
#    - b) HTTP
#    - c) SMTP
#    - d) SSH

# %% [markdown]
# 2. What does URL stand for?
#    - a) Uniform Resource Locator
#    - b) Universal Reference Link
#    - c) Unique Resource Link
#    - d) Uniform Reference Locator

# %% [markdown]
# 3. Which HTTP method is used to send data to a server?
#    - a) GET
#    - b) POST
#    - c) DELETE
#    - d) PUT

# %% [markdown]
# 4. What is the default port for HTTPS?
#    - a) 21
#    - b) 80
#    - c) 443
#    - d) 25

# %% [markdown]
# 5. Which status code means 'Not Found'?
#    - a) 200
#    - b) 301
#    - c) 404
#    - d) 500

# %% [markdown]
# 6. Which of the following is a web browser?
#    - a) Apache
#    - b) Chrome
#    - c) IIS
#    - d) Nginx

# %% [markdown]
# 7. What does HTTP stand for?
#    - a) HyperText Transfer Protocol
#    - b) HighText Transfer Protocol
#    - c) HyperText Transmission Protocol
#    - d) Hyper Transfer Text Protocol

# %% [markdown]
# 8. Which part of a URL specifies the resource location?
#    - a) Protocol
#    - b) Path
#    - c) Query string
#    - d) Fragment

# %% [markdown]
# 9. Which HTTP method is used to retrieve data?
#    - a) POST
#    - b) GET
#    - c) PUT
#    - d) DELETE

# %% [markdown]
# 10. Which of the following is NOT an HTTP status code?
#    - a) 200
#    - b) 404
#    - c) 999
#    - d) 500
