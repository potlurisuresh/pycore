# %% [markdown]
# # Beginner Assessment 2: True/False
# Read each statement and write True or False.

# %% [markdown]
# 1. HTTP is a stateless protocol. (True/False)

# %% [markdown]
# 2. HTTPS uses SSL/TLS for encryption. (True/False)

# %% [markdown]
# 3. A URL can contain a query string. (True/False)

# %% [markdown]
# 4. The GET method is used to delete resources. (True/False)

# %% [markdown]
# 5. HTTP status code 200 means OK. (True/False)

# %% [markdown]
# 6. The POST method is used to retrieve data. (True/False)

# %% [markdown]
# 7. HTTP/2 is faster than HTTP/1.1. (True/False)

# %% [markdown]
# 8. A web server can only serve static files. (True/False)

# %% [markdown]
# 9. The Host header is required in HTTP/1.1. (True/False)

# %% [markdown]
# 10. Cookies are used to store data on the client side. (True/False)
