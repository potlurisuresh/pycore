# %% [markdown]
# # Beginner Assessment 5: Short Answer
# Answer each question in your own words.

# %% [markdown]
# 1. What is a web browser?

# %% [markdown]
# 2. Name one example of a web server.

# %% [markdown]
# 3. What does HTTP stand for?

# %% [markdown]
# 4. What is the main difference between HTTP and HTTPS?

# %% [markdown]
# 5. What is a query string in a URL?

# %% [markdown]
# 6. What is the default port for HTTP?

# %% [markdown]
# 7. What is the function of the GET method?

# %% [markdown]
# 8. Name one HTTP status code and its meaning.

# %% [markdown]
# 9. What is a URL?

# %% [markdown]
# 10. What is the purpose of the Content-Type header?
