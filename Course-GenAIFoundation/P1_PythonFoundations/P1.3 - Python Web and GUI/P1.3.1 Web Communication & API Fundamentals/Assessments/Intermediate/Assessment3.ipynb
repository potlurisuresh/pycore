# %% [markdown]
# # Intermediate Assessment 3: Fill in the Blanks

# %% [markdown]
# 1. The HTTP method used to delete a resource is _______.

# %% [markdown]
# 2. _______ is a lightweight data-interchange format often used in web APIs.

# %% [markdown]
# 3. The response code _______ means the request was successful and there is no content.

# %% [markdown]
# 4. The _______ header tells the server what kind of response the client can accept.

# %% [markdown]
# 5. _______ is a protocol for secure communication over a computer network.

# %% [markdown]
# 6. The _______ method is used to update a resource completely.

# %% [markdown]
# 7. The _______ status code means 'Bad Request'.

# %% [markdown]
# 8. The _______ header is used for authentication.

# %% [markdown]
# 9. The _______ method is used to retrieve only headers.

# %% [markdown]
# 10. The _______ header identifies the client software making the request.
