# %% [markdown]
# # Intermediate Assessment 5: Mixed Questions
# A mix of MCQ, fill in the blanks, and short answer.

# %% [markdown]
# 1. (MCQ) Which of the following is NOT an HTTP method?
# A) GET
# B) POST
# C) FETCH
# D) DELETE

# %% [markdown]
# 2. (Blank) The _____ status code means the resource was not found.

# %% [markdown]
# 3. (Short Answer) What is the purpose of the Host header in HTTP?

# %% [markdown]
# 4. (MCQ) Which format is commonly used for API data exchange?
# A) XML
# B) JSON
# C) CSV
# D) All of the above

# %% [markdown]
# 5. (Blank) _____ is used to secure HTTP connections.

# %% [markdown]
# 6. (Short Answer) What does a 403 status code mean?

# %% [markdown]
# 7. (MCQ) Which tool is commonly used to test APIs?
# A) Postman
# B) Photoshop
# C) Excel
# D) Chrome

# %% [markdown]
# 8. (Blank) The _____ method is used to update a resource completely.

# %% [markdown]
# 9. (Short Answer) What is an endpoint in an API?

# %% [markdown]
# 10. (MCQ) Which status code means 'Created'?
# A) 200
# B) 201
# C) 301
# D) 404
