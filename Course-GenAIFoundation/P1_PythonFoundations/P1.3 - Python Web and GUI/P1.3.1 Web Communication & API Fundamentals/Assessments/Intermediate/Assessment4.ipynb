# %% [markdown]
# # Intermediate Assessment 4: True or False
# State whether each statement is True or False.

# %% [markdown]
# 1. HTTP is a stateless protocol.

# %% [markdown]
# 2. HTTPS uses SSL/TLS for security.

# %% [markdown]
# 3. A 404 status code means 'OK'.

# %% [markdown]
# 4. JSON is a markup language.

# %% [markdown]
# 5. The GET method is used to retrieve data.

# %% [markdown]
# 6. REST APIs can only use the POST method.

# %% [markdown]
# 7. The Content-Type header tells the server what kind of data is being sent.

# %% [markdown]
# 8. A web server can host multiple websites.

# %% [markdown]
# 9. 200 is a success status code.

# %% [markdown]
# 10. An API endpoint is a URL where an API can be accessed.
