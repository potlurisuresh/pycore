# %% [markdown]
# # Intermediate Assessment 1: Multiple Choice
# Choose the correct answer for each question.

# %% [markdown]
# 1. Which protocol is used for secure web communication?
# A) HTTP
# B) FTP
# C) HTTPS
# D) SMTP

# %% [markdown]
# 2. What does an API allow?
# A) Direct database access
# B) Communication between software applications
# C) Hardware control
# D) None of the above

# %% [markdown]
# 3. Which HTTP method is used to update data?
# A) GET
# B) POST
# C) PUT
# D) DELETE

# %% [markdown]
# 4. What is a RESTful API?
# A) An API that uses SOAP
# B) An API that follows REST principles
# C) An API for databases
# D) None of the above

# %% [markdown]
# 5. What is the main function of a web server?
# A) Store emails
# B) Serve web pages
# C) Manage files
# D) Run operating systems

# %% [markdown]
# 6. Which status code means 'Not Found'?
# A) 200
# B) 301
# C) 404
# D) 500

# %% [markdown]
# 7. What is JSON commonly used for?
# A) Styling web pages
# B) Data exchange
# C) Image compression
# D) Video streaming

# %% [markdown]
# 8. Which HTTP method is idempotent?
# A) POST
# B) PUT
# C) PATCH
# D) CONNECT

# %% [markdown]
# 9. What does a 201 status code indicate?
# A) Success
# B) Created
# C) Moved Permanently
# D) Bad Request

# %% [markdown]
# 10. What is the purpose of an API key?
# A) Encrypt data
# B) Authenticate requests
# C) Store cookies
# D) None of the above
