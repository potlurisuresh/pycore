# %% [markdown]
# # Intermediate Assessment 2: Fill in the Blanks
# Fill in the blanks with the correct terms.

# %% [markdown]
# 1. The protocol used for transferring web pages is _____.

# %% [markdown]
# 2. A _____ is a unique address for a web resource.

# %% [markdown]
# 3. _____ is a lightweight data-interchange format.

# %% [markdown]
# 4. The HTTP method used to delete data is _____.

# %% [markdown]
# 5. _____ is a common response status code for success.

# %% [markdown]
# 6. _____ is used to secure HTTP connections.

# %% [markdown]
# 7. The _____ header specifies the type of data sent.

# %% [markdown]
# 8. _____ is a method to send data to a server to create a resource.

# %% [markdown]
# 9. _____ is a tool to test APIs.

# %% [markdown]
# 10. _____ is a common format for API documentation.
