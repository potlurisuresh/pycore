# %% [markdown]
# # Beginner Assessment 2: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. HTTP

# %% [markdown]
# 2. URL

# %% [markdown]
# 3. 404

# %% [markdown]
# 4. HTTPS

# %% [markdown]
# 5. GET

# %% [markdown]
# 6. 200

# %% [markdown]
# 7. Query string

# %% [markdown]
# 8. 80

# %% [markdown]
# 9. Web browser

# %% [markdown]
# 10. Content-Type header
