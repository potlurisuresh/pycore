# %% [markdown]
# # Beginner Assessment 1: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. C) Web browser

# %% [markdown]
# 2. B) HTTP

# %% [markdown]
# 3. A) Uniform Resource Locator

# %% [markdown]
# 4. D) All of the above

# %% [markdown]
# 5. C) 404

# %% [markdown]
# 6. B) HTTPS

# %% [markdown]
# 7. A) GET

# %% [markdown]
# 8. D) 200

# %% [markdown]
# 9. B) Query string

# %% [markdown]
# 10. C) 80
