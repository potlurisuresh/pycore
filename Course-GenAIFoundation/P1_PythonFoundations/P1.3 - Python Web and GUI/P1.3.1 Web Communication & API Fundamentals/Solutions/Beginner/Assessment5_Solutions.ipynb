# %% [markdown]
# # Beginner Assessment 5: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. A web browser is a software application for accessing information on the World Wide Web.

# %% [markdown]
# 2. Example: Apache, Nginx, IIS, etc.

# %% [markdown]
# 3. HyperText Transfer Protocol

# %% [markdown]
# 4. HTTPS is HTTP with encryption/security (SSL/TLS).

# %% [markdown]
# 5. A query string is the part of a URL where data is passed to a web application.

# %% [markdown]
# 6. 80

# %% [markdown]
# 7. GET is used to request data from a server.

# %% [markdown]
# 8. 404 Not Found: The requested resource could not be found.

# %% [markdown]
# 9. URL stands for Uniform Resource Locator, which is the address of a resource on the web.

# %% [markdown]
# 10. The Content-Type header tells the server what type of data is being sent.
