# %% [markdown]
# # Intermediate Assessment 4: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. True

# %% [markdown]
# 2. True

# %% [markdown]
# 3. False

# %% [markdown]
# 4. False

# %% [markdown]
# 5. True

# %% [markdown]
# 6. False

# %% [markdown]
# 7. True

# %% [markdown]
# 8. True

# %% [markdown]
# 9. True

# %% [markdown]
# 10. True
