# %% [markdown]
# # Intermediate Assessment 3: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. To allow communication between software applications.

# %% [markdown]
# 2. GET: Retrieve data; POST: Create data.

# %% [markdown]
# 3. Representational State Transfer.

# %% [markdown]
# 4. 500 is Internal Server Error; it means the server encountered an unexpected condition.

# %% [markdown]
# 5. PUT replaces a resource; POST creates a new resource.

# %% [markdown]
# 6. A JSON object is a collection of key-value pairs.

# %% [markdown]
# 7. It tells the server what content types the client can process.

# %% [markdown]
# 8. An endpoint is a specific URL where an API can be accessed.

# %% [markdown]
# 9. DELETE is used to remove a resource.

# %% [markdown]
# 10. The data sent with a request, usually in POST or PUT.
