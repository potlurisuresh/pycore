# %% [markdown]
# # Intermediate Assessment 2: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. HTTP

# %% [markdown]
# 2. URL

# %% [markdown]
# 3. JSON

# %% [markdown]
# 4. DELETE

# %% [markdown]
# 5. 200

# %% [markdown]
# 6. HTTPS

# %% [markdown]
# 7. Content-Type

# %% [markdown]
# 8. POST

# %% [markdown]
# 9. Postman

# %% [markdown]
# 10. OpenAPI (or Swagger)
