# %% [markdown]
# # Intermediate Assessment 1: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. C) HTTPS

# %% [markdown]
# 2. B) Communication between software applications

# %% [markdown]
# 3. C) PUT

# %% [markdown]
# 4. B) An API that follows REST principles

# %% [markdown]
# 5. B) Serve web pages

# %% [markdown]
# 6. C) 404

# %% [markdown]
# 7. B) Data exchange

# %% [markdown]
# 8. B) PUT

# %% [markdown]
# 9. B) Created

# %% [markdown]
# 10. B) Authenticate requests
