# %% [markdown]
# # Intermediate Assessment 5: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. C) FETCH

# %% [markdown]
# 2. 404

# %% [markdown]
# 3. The Host header specifies the domain name of the server (useful for virtual hosting).

# %% [markdown]
# 4. D) All of the above

# %% [markdown]
# 5. HTTPS

# %% [markdown]
# 6. 403 means Forbidden: the server understood the request but refuses to authorize it.

# %% [markdown]
# 7. A) Postman

# %% [markdown]
# 8. PUT

# %% [markdown]
# 9. An endpoint is a specific URL where an API can be accessed.

# %% [markdown]
# 10. B) 201
