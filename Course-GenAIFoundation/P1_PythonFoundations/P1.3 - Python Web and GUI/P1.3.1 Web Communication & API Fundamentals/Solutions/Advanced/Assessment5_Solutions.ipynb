# %% [markdown]
# # Advanced Assessment 5: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. C) PATCH

# %% [markdown]
# 2. 401

# %% [markdown]
# 3. The Authorization header is used to provide credentials for authenticating a user or client.

# %% [markdown]
# 4. C) 999

# %% [markdown]
# 5. HTTPS

# %% [markdown]
# 6. Statelessness allows easier scaling and reliability because the server does not need to remember client state.

# %% [markdown]
# 7. A) Postman

# %% [markdown]
# 8. PUT

# %% [markdown]
# 9. CORS stands for Cross-Origin Resource Sharing; it controls access to resources from different domains.

# %% [markdown]
# 10. C) 204
