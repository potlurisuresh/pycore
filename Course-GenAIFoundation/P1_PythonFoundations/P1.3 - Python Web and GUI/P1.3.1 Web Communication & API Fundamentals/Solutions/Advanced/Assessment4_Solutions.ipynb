# %% [markdown]
# # Advanced Assessment 4: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. True

# %% [markdown]
# 2. False

# %% [markdown]
# 3. False

# %% [markdown]
# 4. False

# %% [markdown]
# 5. True

# %% [markdown]
# 6. True

# %% [markdown]
# 7. True

# %% [markdown]
# 8. False

# %% [markdown]
# 9. True

# %% [markdown]
# 10. True
