# %% [markdown]
# # Advanced Assessment 2: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. Content-Type

# %% [markdown]
# 2. HTTPS

# %% [markdown]
# 3. HEAD

# %% [markdown]
# 4. OpenAPI (or Swagger)

# %% [markdown]
# 5. Postman

# %% [markdown]
# 6. 403

# %% [markdown]
# 7. JSON

# %% [markdown]
# 8. PATCH

# %% [markdown]
# 9. CORS

# %% [markdown]
# 10. 400
