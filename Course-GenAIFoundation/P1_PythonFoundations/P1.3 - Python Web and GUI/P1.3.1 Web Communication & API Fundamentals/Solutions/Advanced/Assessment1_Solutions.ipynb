# %% [markdown]
# # Advanced Assessment 1: Solutions
# Reference answers for all questions.

# %% [markdown]
# 1. B) Authorization

# %% [markdown]
# 2. A) Cross-Origin Resource Sharing

# %% [markdown]
# 3. B) 401

# %% [markdown]
# 4. B) Scalability

# %% [markdown]
# 5. C) POST

# %% [markdown]
# 6. C) Describe communication options

# %% [markdown]
# 7. D) MP3

# %% [markdown]
# 8. A) No Content

# %% [markdown]
# 9. B) PATCH

# %% [markdown]
# 10. B) Easier scaling
